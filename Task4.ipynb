# %% [markdown]
# Day 4 Assignment – Object-Oriented Programming (OOP)
#
#
# Name-Sai Prasad Neelmani
#
# Learning Objectives
#
# Understand how to create reusable and scalable programs using classes and objects.
#
# ---

# %% [markdown]
# Theory Topics (Self Study)

# %% [markdown]
# 1. Classes and Objects
# Class
#
# A class is a blueprint or template used to create objects. It defines the attributes and methods that objects will have.
#
# Object
#
# An object is an instance of a class. It represents a real-world entity and can access the class's attributes and methods.

# %%
class Student:
    pass

s1 = Student()

# %% [markdown]
# ---

# %% [markdown]
# 2. Constructors (__init__)
#
# A constructor is a special method that is automatically called when an object is created. In Python, the constructor is defined using __init__().

# %%
class Student:
    def __init__(self, name):
        self.name = name

s1 = Student("Sai")

# %% [markdown]
# ---
#
# 3. Instance Variables and Methods
# Instance Variables
#
# Variables that belong to a specific object. Each object has its own copy.
#
# Instance Methods
#
# Methods that work with instance variables and use the self parameter.

# %%
class Student:
    def __init__(self, name):
        self.name = name

    def display(self):
        print(self.name)

s1 = Student("Sai")
s1.display()
# Out:
# Sai

# %% [markdown]
# ---
#
# 4. Class Variables
#
# Class variables are shared among all objects of a class. They are defined inside the class but outside any method.

# %%
class Student:
    school = "ABC School"

s1 = Student()
s2 = Student()

print(s1.school)
print(s2.school)

# %% [markdown]
# ---
# 5. Encapsulation
#
# Encapsulation is the process of wrapping data and methods into a single unit and restricting direct access to data.

# %%
class BankAccount:
    def __init__(self):
        self.__balance = 1000

    def get_balance(self):
        return self.__balance

obj = BankAccount()
print(obj.get_balance())

# %% [markdown]
# ---
# 6. Inheritance
#
# Inheritance allows one class to inherit properties and methods from another class.

# %%
class Employee:
    def work(self):
        print("Working")

class Manager(Employee):
    pass

m = Manager()
m.work()

# %% [markdown]
# ---
#
# 7. Polymorphism
#
# Polymorphism means "many forms." The same method name can have different behaviors in different classes.

# %%
class Car:
    def start(self):
        print("Car starts with key")

class Bike:
    def start(self):
        print("Bike starts with self-start")

vehicles = [Car(), Bike()]

for v in vehicles:
    v.start()

# %% [markdown]
# ---
#
# 8. Abstraction
#
# Abstraction hides implementation details and shows only essential information to the user.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

class Rectangle(Shape):
    def area(self):
        return 10 * 5

# %% [markdown]
# ---
# 9. Method Overriding
#
# Method overriding occurs when a child class provides its own implementation of a method already defined in the parent class.

# %%
class Animal:
    def sound(self):
        print("Animal Sound")

class Dog(Animal):
    def sound(self):
        print("Bark")

d = Dog()
d.sound()
# Out:
# Bark

# %% [markdown]
# ---
# 10. super() Function
#
# The super() function is used to call methods or constructors of the parent class.

# %%
class Parent:
    def __init__(self):
        print("Parent Constructor")

class Child(Parent):
    def __init__(self):
        super().__init__()
        print("Child Constructor")

c = Child()
# Out:
# Parent Constructor
# Child Constructor

# %% [markdown]
# ---
# 11. Access Modifiers
#
# Access modifiers control the visibility and accessibility of variables and methods.
#
# Public Members
#
# Accessible from anywhere.

# %%
class Demo:
    name = "Sai"

# %% [markdown]
# Protected Members
#
# Accessible within the class and subclasses.

# %%
class Demo:
    _name = "Sai"

# %% [markdown]
# Private Members
#
# Accessible only within the class.

# %%
class Demo:
    __name = "Sai"

# %% [markdown]
# ---
#
# Main Task
# ---------
#
# Create Python programs using OOP concepts.

# %% [markdown]
# ---
#
# Subtask
#
# 1. Create Classes and Objects
#
# A class is a blueprint for creating objects, and an object is an instance of a class.

# %%
class Student:
    pass

s1 = Student()
print("Object Created")
# Out:
# Object Created

# %% [markdown]
# ---
#
# 2. Use Constructors
#
# A constructor (__init__) is automatically called when an object is created and is used to initialize object attributes.

# %%
class Student:
    def __init__(self, name):
        self.name = name

s1 = Student("Sai")
print(s1.name)
# Out:
# Sai

# %% [markdown]
# ---
# 3. Define Attributes and Methods
#
# Attributes store data, while methods define the actions an object can perform.

# %%
class Student:
    def __init__(self, name):
        self.name = name

    def display(self):
        print("Name:", self.name)

s1 = Student("Sai")
s1.display()
# Out:
# Name: Sai

# %% [markdown]
# ---
#
# 4. Implement Inheritance
#
# Inheritance allows a child class to acquire properties and methods from a parent class.

# %%
class Employee:
    def work(self):
        print("Employee Working")

class Manager(Employee):
    pass

m = Manager()
m.work()
# Out:
# Employee Working

# %% [markdown]
# ---
# 5. Demonstrate Polymorphism
#
# Polymorphism allows the same method name to behave differently in different classes.

# %%
class Car:
    def start(self):
        print("Car Starts")

class Bike:
    def start(self):
        print("Bike Starts")

vehicles = [Car(), Bike()]

for v in vehicles:
    v.start()
# Out:
# Car Starts
# Bike Starts

# %% [markdown]
# ---
# 6. Apply Encapsulation
#
# Encapsulation hides data from direct access and provides controlled access through methods.

# %%
class BankAccount:
    def __init__(self):
        self.__balance = 1000

    def get_balance(self):
        return self.__balance

obj = BankAccount()
print(obj.get_balance())
# Out:
# 1000

# %% [markdown]
# ---
# 7. Use Abstraction
#
# Abstraction hides implementation details and shows only essential features.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Rectangle(Shape):
    def area(self):
        return 20

r = Rectangle()
print(r.area())
# Out:
# 20

# %% [markdown]
# ---
# 8. Override Methods
#
# Method overriding occurs when a child class provides its own implementation of a parent class method.

# %%
class Animal:
    def sound(self):
        print("Animal Sound")

class Dog(Animal):
    def sound(self):
        print("Bark")

d = Dog()
d.sound()
# Out:
# Bark

# %% [markdown]
# ---
#
# 9. Use Class and Instance Variables
# Class Variable
#
# Shared by all objects of the class.
#
# Instance Variable
#
# Unique to each object.

# %%
class Student:
    school = "ABC School"    # Class Variable

    def __init__(self, name):
        self.name = name     # Instance Variable

s1 = Student("Sai")
s2 = Student("Yash")

print(s1.school)
print(s2.school)

print(s1.name)
print(s2.name)
# Out:
# ABC School
# ABC School
# Sai
# Yash

# %% [markdown]
# ---
# Practice Assignments
# ====================
#
# 1. Student Management System

# %%
class Student:
    def __init__(self, name, roll_number, marks):
        self.name = name
        self.roll_number = roll_number
        self.marks = marks

    def calculate_grade(self):
        if self.marks >= 90:
            return "A"
        elif self.marks >= 75:
            return "B"
        elif self.marks >= 60:
            return "C"
        else:
            return "D"

    def display_details(self):
        print("Student Name:", self.name)
        print("Roll Number:", self.roll_number)
        print("Marks:", self.marks)
        print("Grade:", self.calculate_grade())


# Creating Object
student1 = Student("Sai Prasad", 101, 88)

# Display Details
student1.display_details()
# Out:
# Student Name: Sai Prasad
# Roll Number: 101
# Marks: 88
# Grade: B

# %% [markdown]
# ---
#
# 2. Bank Account System (Encapsulation)

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance   # Private Variable

    def deposit(self, amount):
        self.__balance += amount
        print(f"₹{amount} deposited successfully.")

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            print(f"₹{amount} withdrawn successfully.")
        else:
            print("Insufficient Balance!")

    def check_balance(self):
        print("Current Balance: ₹", self.__balance)


# Creating Object
account = BankAccount(5000)

# Operations
account.check_balance()
account.deposit(2000)
account.withdraw(1500)
account.check_balance()
# Out:
# Current Balance: ₹ 5000
# ₹2000 deposited successfully.
# ₹1500 withdrawn successfully.
# Current Balance: ₹ 5500

# %% [markdown]
# ---
#
# 3. Employee Management (Inheritance)

# %%
class Employee:
    def work(self):
        print("Employee is working")


class Manager(Employee):
    def manage(self):
        print("Manager is managing the team")


# Creating Object of Child Class
manager1 = Manager()

# Accessing Parent Class Method
manager1.work()

# Accessing Child Class Method
manager1.manage()
# Out:
# Employee is working
# Manager is managing the team

# %% [markdown]
# ---
#
# 4.Vehicle System (Polymorphism)

# %%
class Vehicle:
    def start(self):
        print("Vehicle starts")


class Car(Vehicle):
    def start(self):
        print("Car starts with key")


class Bike(Vehicle):
    def start(self):
        print("Bike starts with self-start")


# Creating Objects
car = Car()
bike = Bike()

# Demonstrating Polymorphism
car.start()
bike.start()
# Out:
# Car starts with key
# Bike starts with self-start

# %% [markdown]
# ---
#
# 5.Shape Area Calculator (Abstraction)

# %%
from abc import ABC, abstractmethod

# Abstract Class
class Shape(ABC):

    @abstractmethod
    def area(self):
        pass


# Child Class
class Rectangle(Shape):
    def __init__(self, length, breadth):
        self.length = length
        self.breadth = breadth

    def area(self):
        return self.length * self.breadth


# Creating Object
rect = Rectangle(10, 5)

# Display Area
print("Area of Rectangle:", rect.area())
# Out:
# Area of Rectangle: 50

# %% [markdown]
# ---
#
# 6. Library Management System (Mini Project)

# %%
class Book:
    def __init__(self, title):
        self.title = title
        self.is_issued = False


class Member:
    def __init__(self, name):
        self.name = name


class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)
        print(f'"{book.title}" added to library.')

    def issue_book(self, title):
        for book in self.books:
            if book.title == title and not book.is_issued:
                book.is_issued = True
                print(f'"{title}" has been issued.')
                return
        print(f'"{title}" is not available.')

    def return_book(self, title):
        for book in self.books:
            if book.title == title and book.is_issued:
                book.is_issued = False
                print(f'"{title}" has been returned.')
                return
        print(f'"{title}" was not issued.')

    def display_available_books(self):
        print("\nAvailable Books:")
        available = False

        for book in self.books:
            if not book.is_issued:
                print("-", book.title)
                available = True

        if not available:
            print("No books available.")


# Creating Library Object
library = Library()

# Adding Books
library.add_book(Book("Python Programming"))
library.add_book(Book("Data Structures"))
library.add_book(Book("Machine Learning"))

# Display Available Books
library.display_available_books()

# Issue a Book
library.issue_book("Python Programming")

# Display Available Books Again
library.display_available_books()

# Return the Book
library.return_book("Python Programming")

# Display Available Books Again
library.display_available_books()
# Out:
# "Python Programming" added to library.
# "Data Structures" added to library.
# "Machine Learning" added to library.
#
# Available Books:
# - Python Programming
# - Data Structures
# - Machine Learning
# "Python Programming" has been issued.
#
# Available Books:
# - Data Structures
# - Machine Learning
# "Python Programming" has been returned.
#
# Available Books:
# - Python Programming
# - Data Structures
# - Machine Learning
